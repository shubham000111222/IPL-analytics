# %% [markdown]
# # IPL EDA
#
# Initial exploratory analysis for the IPL dataset.

# %%
from pathlib import Path
import pandas as pd

root = Path('..').resolve()
matches = pd.read_csv(root / 'data' / 'raw' / 'matches.csv')
deliveries = pd.read_csv(root / 'data' / 'raw' / 'deliveries.csv')

matches.head()
